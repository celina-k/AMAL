# %% [markdown]
# ### Etudiant 1: GIANG Phuong Thu, Cécile (3530406)
# ### Etudiant 2: KHALFAT Célina (28716860)

# %% [markdown]
# # [AMAL] TME 5: Réseaux récurrents, LSTM, GRU et autres cellules à mémoire

# %%
from tp5 import *

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Avec RNN

# %% [markdown]
# **Séquences générées:**

# %%
train_model(RNN, embed_dim = 60, latent_dim = len(lettre2id), output_dim = len(lettre2id) + 1, epsilon = 1e-3, start = list_start, maxsent = None, maxlen = 42)
# Out:
#  ------- GREEDY GENERATION : -------
#
# Than --> Thank you know the American protect is the pe
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Than --> Thank you know what we are going to have to b.
# Than --> Thank you..
# Than --> Thank you know what we are going to have that.
# Than --> Thank you..
# Than --> Thank you..
# Than --> Thank..
# Than --> Thank you..
# None
#
#  ------- GREEDY GENERATION : -------
#
# [appl --> [applause] The people that we will be the peop
#
#  ------- BEAM SEARCH GENERATION : -------
#
# [appl --> [applause] We will Make American people that w.
# [appl --> [applause] We will Make American president of .
# [appl --> [applause] We will Make American president the.
# [appl --> [applause] We will Make American president tha.
# [appl --> [applause] We're going to have that we will Ma.
# [appl --> [applause] We're going to have that we will be.
# [appl --> [applause] We're going to have that we are goi.
# None
#
#  ------- GREEDY GENERATION : -------
#
# We are --> We are going to be the people that we will be t
#
#  ------- BEAM SEARCH GENERATION : -------
#
# We are --> We are going to have that we are going to be th.
# We are --> We are going to have that we are going to have .
# We are --> We are going to have that we are going to be th.
# We are --> We are going to have that we will Make American.
# We are --> We are going to have that we are going to bring.
# We are --> We are going to have that we are going to have .
# We are --> We are going to have that we will Make American.
# None
#
#  ------- GREEDY GENERATION : -------
#
# Our country --> Our country and the people that we will be the peopl
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Our country --> Our country..
# Our country --> Our country..
# Our country --> Our country..
# Our country --> Our country..
# Our country --> Our country..
# Our country --> Our country..
# Our country --> Our country..
# None
#
#  ------- GREEDY GENERATION : -------
#
# Hil --> Hillary Clinton are a lot that we will be th
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Hil --> Hillary Clinton have that we are going to br.
# Hil --> Hillary Clinton have that we are going to re.
# Hil --> Hillary Clinton have that we are going to do.
# Hil --> Hillary Clinton have that we are going to ha.
# Hil --> Hillary Clinton have that we will Make Ameri.
# Hil --> Hillary Clinton have that we are going to be.
# Hil --> Hillary..
# None
#
#  ------- GREEDY GENERATION : -------
#
# This is --> This is the people that we will be the people th
#
#  ------- BEAM SEARCH GENERATION : -------
#
# This is --> This is going to have that we are going to be th.
# This is --> This is going to have that we are going to have .
# This is --> This is going to have that we are going to be th.
# This is --> This is going to have that we will Make American.
# This is --> This is going to have that we are going to bring.
# This is --> This is going to have that we are going to have .
# This is --> This is going to have that we will Make American.
# None
#
#  ------- GREEDY GENERATION : -------
#
# I am --> I am going to be the people that we will be t
#
#  ------- BEAM SEARCH GENERATION : -------
#
# I am --> I am going to have that we are going to be th.
# I am --> I am going to have that we are going to have .
# I am --> I am going to have that we are going to be th.
# I am --> I am going to have that we will Make American.
# I am --> I am going to have that we are going to bring.
# I am --> I am going to have that we are going to have .
# I am --> I am going to have that we will Make American.
# None
#
#  ------- GREEDY GENERATION : -------
#
# The world --> The world we will be the people that we will be th
#
#  ------- BEAM SEARCH GENERATION : -------
#
# The world --> The world..
# The world --> The world..
# The world --> The world..
# The world --> The world..
# The world --> The world..
# The world --> The world we are going to have that..
# The world --> The world..
# None
#
#  ------- GREEDY GENERATION : -------
#
# The U --> The Unition with the people that we will be th
#
#  ------- BEAM SEARCH GENERATION : -------
#
# The U --> The U..
# The U --> The U..
# The U --> The U..
# The U --> The U..
# The U --> The Unitting thank you..
# The U --> The Unition..
# The U --> The U..
# None
#
#  ------- GREEDY GENERATION : -------
#
# Our gov --> Our government of the people that we will be the
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Our gov --> Our government..
# Our gov --> Our government..
# Our gov --> Our govern..
# Our gov --> Our govern..
# Our gov --> Our government..
# Our gov --> Our gover..
# Our gov --> Our govern..
# None
#
#  ------- GREEDY GENERATION : -------
#
# We w --> We will be the people that we will be the peo
#
#  ------- BEAM SEARCH GENERATION : -------
#
# We w --> We will Make American president that we will .
# We w --> We will Make American president that we will .
# We w --> We will Make American president that we will .
# We w --> We will Make American president thank you kno.
# We w --> We will Make American people..
# We w --> We will Make America..
# We w --> We will Make Amer..
# None

# %% [markdown]
# **Evolution de la loss en entraînement:**

# %% [markdown]
# ![RNN_emb60_lat97.png](attachment:RNN_emb60_lat97.png)

# %% [markdown]
# ## Avec LSTM

# %% [markdown]
# **Séquences générées:**

# %%
train_model(LSTM, embed_dim = 60, latent_dim = len(lettre2id), output_dim = len(lettre2id) + 1, epsilon = 1e-3, start = list_start, maxsent = None, maxlen = 42)
# Out:
#  ------- GREEDY GENERATION : -------
#
# Than --> Thane of the s.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Than --> Thane alll.alllalllalllllallllalllalll.l......
# Than --> Thane alll.alllalllalllllalllallllalll.l......
# Than --> Thane alll.alllalllalllllalllallllalll........
# Than --> Thane alll.alllalllalllllallllalllalll........
# Than --> Thane alllal.le.lell.....
# Than --> Thane alll.alllalllalllllalllalllllalll.......
# Than --> Thane all.all.ee...
# None
#
#  ------- GREEDY GENERATION : -------
#
# [appl --> [applast, I want.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# [appl --> [applaalalleeeallelllllllllllallllllllalllllll.
# [appl --> [applaalalleeeallellllllllllelllllellllllelll..
# [appl --> [applaallaleeeallellllllllllallllllallllllllla.
# [appl --> [applaalalleeeallellllllllllelllllelllllellll..
# [appl --> [applaalalleealeee.ee...
# [appl --> [applaalalleealeeee.leee...
# [appl --> [applaalalleealeeee.lee...
# None
#
#  ------- GREEDY GENERATION : -------
#
# We are --> We aret and we ar.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# We are --> We aretilallelll.lllell.l.....
# We are --> We aretilallell.lee...
# We are --> We aretalll.ee...
# We are --> We aretal.ee..
# We are --> We aretall..ee.
# We are --> We aretal..e.
# We are --> We aretall.ee...
# None
#
#  ------- GREEDY GENERATION : -------
#
# Our country --> Our countrye and we ar.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Our country --> Our countryeestreeetreelletlelllelll.l.......
# Our country --> Our countryeesterelletreelletlerelletreeretree.......
# Our country --> Our countryeesterelletleerellletlelllell.l...........
# Our country --> Our countryeestreeetreelletlelllelll.ll..............
# Our country --> Our countryeeletlellllllllallllllalll.lll............
# Our country --> Our countryeeletlellllllllallllllallll.ll............
# Our country --> Our countryeeletlellllllllallllllalll.ll.............
# None
#
#  ------- GREEDY GENERATION : -------
#
# Hil --> Hilling to the.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Hil --> Hillalallallallallalllallllalllelllelllel.ll.
# Hil --> Hillaallalllalllallllalllallllalllallllallll.
# Hil --> Hillalallallallallalllalllalllelllelllelll.l.
# Hil --> Hillaallalllalllallllalllallllalllallllallla.
# Hil --> Hillalallallallallalllalllalllelllelllell.ll.
# Hil --> Hillaallalllalllallllalllallllallllalllallll.
# Hil --> Hillaallalllalllallllallllalllallllalllallll.
# None
#
#  ------- GREEDY GENERATION : -------
#
# This is --> This ision the state.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# This is --> This isillilllalllelllelllllllllelllllellllllll..
# This is --> This isillilllalllelllelllllllllelllllelllllll.l.
# This is --> This isillilllalllelllellllllllllelllllellllll.l.
# This is --> This isillell.le.elll.ll.l.....
# This is --> This isillalllell.lelllell.le....................
# This is --> This isillell.le...
# This is --> This isillell.lee...
# None
#
#  ------- GREEDY GENERATION : -------
#
# I am --> I am into the s.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# I am --> I am it inllle.l.e..
# I am --> I am inll.all.ee..
# I am --> I am....
# I am --> I am inll.ee...
# I am --> I am inll.aee...
# I am --> I am inll..e..
# I am --> I ami...
# None
#
#  ------- GREEDY GENERATION : -------
#
# The world --> The worlde and we ar.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# The world --> The worldeeteeretleeteettlellelllllelllllel........
# The world --> The worldeeteeretleeteettlellelllllelllell.l.......
# The world --> The worldeeteeretleeteettlelllelllelllelll.l.......
# The world --> The worldeeteeretleeteettlelllelllelllell.l........
# The world --> The worldeeteer.eee..
# The world --> The worldeeteee...
# The world --> The worldeetee...
# None
#
#  ------- GREEDY GENERATION : -------
#
# The U --> The Uin of the s.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# The U --> The Uillillalllalllllelllelllllelllllelllllell.
# The U --> The Uillal.le....
# The U --> The Uillall.le...
# The U --> The Uillal.le...
# The U --> The Uillall.lee...
# The U --> The Uillall.le....
# The U --> The Uill..e.
# None
#
#  ------- GREEDY GENERATION : -------
#
# Our gov --> Our goven we are go.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# Our gov --> Our govetetteer.eelllell.l....
# Our gov --> Our govetetteer.eelllell.l.....
# Our gov --> Our goveteteer.leee...
# Our gov --> Our govet..e.
# Our gov --> Our goveteet.ee..
# Our gov --> Our govetteer.ee..
# Our gov --> Our govet....
# None
#
#  ------- GREEDY GENERATION : -------
#
# We w --> We wi of the s.<EOS>
#
#  ------- BEAM SEARCH GENERATION : -------
#
# We w --> We willll.letarelellelllllllllalllllllalllll..
# We w --> We willll.letereteettlellelllllllllllell.l....
# We w --> We willll.le.....
# We w --> We willll..e..
# We w --> We willl..ee..
# We w --> We willll.le....
# We w --> We willll..ee..
# None

# %% [markdown]
# **Evolution de la loss en entraînement**

# %% [markdown]
# ![LSTM_emb60_lat97.png](attachment:LSTM_emb60_lat97.png)

# %% [markdown]
# ## Avec GRU

# %%
train_model(GRU, embed_dim = 60, latent_dim = len(lettre2id), output_dim = len(lettre2id) + 1, epsilon = 1e-3, start = list_start, maxsent = None, maxlen = 42)

# %% [markdown]
# **Evolution de la loss en entraînement:**

# %% [markdown]
# ![GRU_emb60_lat97.PNG](attachment:GRU_emb60_lat97.PNG)

# %% [markdown]
# Bien que la loss du RNN et du LSTM convergent toutes 2 vers 1.2, les performances du RNN en terme analytique semblent meilleures. Il semblerait que notre modèle LSTM n'ai exploité sa mémoire qu'à court terme...
