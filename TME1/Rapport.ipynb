# %% [markdown]
# ### Etudiant 1: GIANG Phuong-Thu, Cécile (3530406)
# ### Etudiant 1: KHALFAT Célina (28716860)

# %% [markdown]
# # TME 1 - Définition de fonctions en `PyTorch`

# %% [markdown]
# ## 1 - Implémentation de fonctions

# %%
# Importation de la classe Context et des fonctions MSE et Linear
import tp1

# %% [markdown]
# `PyTorch` nous permet de tester la fonction `backward` de nos classes `MSE` et `Linear` grâce à sa fonction `gradcheck` qui effectue une approximation numérique par différence finie. Elle renvoie `True` si notre calcul de dérivées est correcte, `False` sinon.
#
# Dans le cadre de notre test, nous tirons aléatoirement les entrées de nos fonctions:
# - pour `MSE`: `y` et `yhat` sont deux tenseurs de taille (10,5)
# - pour `Linear`: nous tirons `x` de taille (10,5), `w` de taille (5,7) et `b` de taille (1,7)

# %%
# Gradcheck
import tp1_gradcheck
# Out:
# Gradcheck for MSE function :  True
# Gradcheck for Linear function :  True

# %% [markdown]
# ## 2 - Descente de gradient

# %% [markdown]
# Afin de tester notre descente de gradient, nous tirons aléatoirement nos exemples:
# - `x` est notre ensemble d'échantillons, de taille (50, 13)
# - `y` est notre ensemble d'étiquettes, de taille (50, 3)
#
# Nous affichons ci-dessous la loss en entraînement qui décroît bien au fil des itérations.

# %%
import tp1_descente
# Out:
# Itérations 0: loss 21.29368782043457
# Itérations 1: loss 19.488248825073242
# Itérations 2: loss 17.877246856689453
# Itérations 3: loss 16.437299728393555
# Itérations 4: loss 15.148024559020996
# Itérations 5: loss 13.991623878479004
# Itérations 6: loss 12.9525728225708
# Itérations 7: loss 12.017293930053711
# Itérations 8: loss 11.173910140991211
# Itérations 9: loss 10.412022590637207
# Itérations 10: loss 9.722521781921387
# Itérations 11: loss 9.097412109375
# Itérations 12: loss 8.529670715332031
# Itérations 13: loss 8.013121604919434
# Itérations 14: loss 7.542333126068115
# Itérations 15: loss 7.112514495849609
# Itérations 16: loss 6.7194366455078125
# Itérations 17: loss 6.359365463256836
# Itérations 18: loss 6.028995037078857
# Itérations 19: loss 5.725396156311035
# Itérations 20: loss 5.445969581604004
# Itérations 21: loss 5.188405990600586
# Itérations 22: loss 4.950650215148926
# Itérations 23: loss 4.730869293212891
# Itérations 24: loss 4.527427673339844
# ...

# %% [markdown]
# Nous pouvons visualiser les graphes correspondant à l'évolution de la loss en apprentissage grâce à `tensorboard`.

# %% [markdown]
# ![loss.PNG](attachment:loss.PNG)
