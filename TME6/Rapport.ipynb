# %% [markdown]
# ### Etudiant 1: GIANG Phuong Thu, Cécile (3530406)
# ### Etudiant 2: KHALFAT Célina (28716860)

# %% [markdown]
# # [AMAL] TME 5: Réseaux récurrents - Séquences à séquences (seq2seq)

# %% [markdown]
# ## Tagging

# %%
from tagging import *

import warnings
warnings.filterwarnings('ignore')
# Out:
# INFO:root:Loading datasets...
# INFO:root:Vocabulary size: 2

# %% [markdown]
# L'apprentissage du modèle d'étiquetage est très lourd et très long (environ 4 heures pour 50 époques).
#
# Nous avons donc choisi de le lancer directement sur notre IDE au lieu de le lancer sur notebook, puis d'enregistrer notre nodèle dans le fichier `Tagging_emb60_lat50.pch`.
#
# Les images ci-dessous sont des captures de l'évolution de la loss en entraînement et en test.

# %% [markdown]
# **Affichage de la loss en entraînement:**
#
# <table>
#   <tr>
#     <td><img src="tagging_60_50_loss.PNG" width=450 height=500></td>
#   </tr>
#  </table>

# %% [markdown]
# **Evolution des loss en entraînement et en test:**
#
# <table>
#   <tr>
#     <td><img src="train_tagging_60_50.PNG" width=300 height=480></td>
#     <td><img src="test_tagging_60_50.PNG" width=300 height=480></td>
#   </tr>
#  </table>

# %% [markdown]
# **Illustration de quelques séquences d'étiquettes syntaxiques générées en entraînement:**

# %%
## On ouvre un modèle déjà entraîné
state = torch.load('Tagging_emb60_lat50.pch')

for i in range(10):
    print('\n\n\n\n------- Exemple {}: -------\n\n'.format(i))
    ## Vérifier une séquence de tags générée
    x, y = next(iter(train_loader))
    model = state.model

    # x_ et y_ la 1ère phrase du batch et les tags correspondants
    x_ = x[:,0]
    y_ = y[:,0]

    # yhat les probabilités associées à chaque tag pour chaque mot
    yhat = model(x_)

    # preds la séquence de tags prédite sur x_
    preds = torch.stack([torch.argmax(e) for e in yhat])

    # Affichage des tags prédits (preds) et des tags attendus (y_)
    print('Phrase : \n', words.getwords(x_))
    print('\n\nTags prédits: \n', tags.getwords(preds))
    print('\n\nTags attendus: \n', tags.getwords(y_))
# Out:
# ------- Exemple 0: -------
#
#
# Phrase :
#  ['Elle', 'a', 'fait', 'partie', 'de', "l'", 'indice', 'TecDAX', 'de', '2004', 'à', '2009', ',', 'puis', 'y', 'été', 'réintégrée', 'en', 'mars', '2010', '.', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
#
#
# Tags prédits:
# ...

# %% [markdown]
# **Illustration de quelques séquences d'étiquettes syntaxiques générées en test:**

# %%
## On ouvre un modèle déjà entraîné
state = torch.load('Tagging_emb60_lat50.pch')

for i in range(10):
    print('------- Exemple {}: -------\n'.format(i))
    ## Vérifier une séquence de tags générée
    x, y = next(iter(test_loader))
    model = state.model

    # x_ et y_ la 1ère phrase du batch et les tags correspondants
    x_ = x[:,0]
    y_ = y[:,0]

    # yhat les probabilités associées à chaque tag pour chaque mot
    yhat = model(x_)

    # preds la séquence de tags prédite sur x_
    preds = torch.stack([torch.argmax(e) for e in yhat])

    # Affichage des tags prédits (preds) et des tags attendus (y_)
    print('Phrase : \n', words.getwords(x_))
    print('\n\nTags prédits: \n', tags.getwords(preds))
    print('\n\nTags attendus: \n\n\n', tags.getwords(y_))
# Out:
# ------- Exemple 0: -------
#
# Phrase :
#  ['__OOV__', ',', 'un', 'film', 'sur', 'la', 'vie', 'de', 'Hughes', '.', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD', 'PAD']
#
#
# Tags prédits:
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# Le modèle fonctionne plutôt bien, bien qu'il n'ait étét entraîné que sur 50 époques pour des batchs de taille 128.
# En entraînement, la loss se stabilise autour de 0,04 tandis que la loss en test est plus élevé (0.1) et commence même à monter à partir de l'époque 25.

# %% [markdown]
# ## Traduction

# %% [markdown]
# Une ébauche du code pour entraîner un modèle de traduction a été implémenté (`translation.py`), mais il ne fonctionne malheureusement pas. Nous avons tout de même laissé le code dans l'archive rendue.
